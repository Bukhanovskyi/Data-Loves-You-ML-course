# %% [markdown]
# **1. Списки - базові операції**
#
# Створіть список температур за тиждень (у градусах Цельсія) з назвою
# `temperatures` і значеннями [22, 25, 19, 23, 26, 20, 21, 22].
#
#
# Виконайте (кожен пункт оцінюється в 0.5 бала):
# - Виведіть перший елемент
# - Виведіть останній елемент
# - Додайте температуру 24
# - Видаліть температуру 19
# - Виведіть довжину списку
# - Обчисліть суму всіх температур
# - Знайдіть максимальну температуру

# %%
temperatures = [22, 25, 19, 23, 26, 20, 21, 22]

# %%
print('оригінальний список: ' + str(temperatures))
#Виведіть перший елемент
print('перший елемент: ' +  str(temperatures[0]))

#Виведіть останній елемент
print('останній елемент: ' + str(temperatures[-1]))

# Додайте температуру 24
temperatures.append(24)
print('додано 24: ' + str(temperatures))

#Видаліть температуру 19
temperatures.remove(19)
print('без 19: ' + str(temperatures))

#Виведіть довжину списку
print('довжинa списку: ' + str(len(temperatures)))

#Обчисліть суму всіх температур
print('сумa температур: ' + str(sum(temperatures)))

#Знайдіть максимальну температуру
print('максимальнa температурa: ' + str(max(temperatures)))
# Out:
# оригінальний список: [22, 25, 19, 23, 26, 20, 21, 22]
# перший елемент: 22
# останній елемент: 22
# додано 24: [22, 25, 19, 23, 26, 20, 21, 22, 24]
# без 19: [22, 25, 23, 26, 20, 21, 22, 24]
# довжинa списку: 8
# сумa температур: 183
# максимальнa температурa: 26

# %% [markdown]
# **2. Словники - базові операції**
#
# Створіть словник про себе, який містить ключі `name`, `age`, `city` і значення, які відповідають вашему імені, віку і місту (можна вставити будь-які значення, не обовʼязково свої).
#
#
# Виконайте (кожен пункт оцінюється в 0.5 бала):
# - Виведіть значення ключа "name"
# - Змініть значення ключа "age" на 21
# - Додайте новий ключ "hobby" зі значенням "programming"
# - Виведіть всі ключі
# - Виведіть всі значення

# %%
dict1 = {
    'name': 'Yaroslav',
    'age': 30,
    'city': 'Kyiv'
}

# %%
# Виведіть значення ключа "name"
print('значення ключа "name": ', dict1['name'])
# Змініть значення ключа "age" на 21

dict1['age'] = 21
print('значення ключа "age": ', dict1['age'])

# Додайте новий ключ "hobby" зі значенням "programming"
dict1['hobby'] = 'programming'
print('оновлений словник: ', dict1)

# Виведіть всі ключі
print('ключі: ', list(dict1.keys()))

# Виведіть всі значення
print('значення: ', list(dict1.values()))
# Out:
# значення ключа "name":  Yaroslav
# значення ключа "age":  21
# оновлений словник:  {'name': 'Yaroslav', 'age': 21, 'city': 'Kyiv', 'hobby': 'programming'}
# ключі:  ['name', 'age', 'city', 'hobby']
# значення:  ['Yaroslav', 21, 'Kyiv', 'programming']
